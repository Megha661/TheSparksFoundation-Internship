# %% [markdown]
# # THE SPARKS FOUNDATION
# # DATA SCIENCE AND BUSINESS ANALYTICS INTERNSHIP JUNE-2021
#
# ## Submitted By : Megha Verma

# %% [markdown]
# # Task 3 - Exploratory Data Analysis - Retail

# %% [markdown]
# ### Problem Statement : Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’ . As a business manager, try to find out the weak areas where you can work to make more profit. What all business problems you can derive by exploring the data?

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
sns.set_style("darkgrid")

# %% [markdown]
# # 1) Understanding the dataset

# %%
df = pd.read_csv('C://Users//DEEPAK//Downloads//SampleSuperstore.csv')  #loading dataset
df  #display the dataset
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.head()  #display first 5 rows of dataset
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.tail()   #display the bottom 5 rows of dataset
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
df.shape     #displayes the total no of rows and columns
# Out:
# (9994, 13)

# %%
df.describe()   #displays the summary
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.isnull().sum()   #checking the null values
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 17

# %%
df.nunique()   # finding the number of unique values in each column
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
df['Postal Code'] = df['Postal Code'].astype('object')

# %%
df.drop_duplicates(subset=None,keep='first',inplace=True)
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Finding the correlation

# %%
corr = df.corr()
sns.heatmap(corr,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
plt.style.use('seaborn')
df.plot(kind = "scatter",figsize = (10,5), x = "Sales", y= "Profit", c = "Discount", s = 20,fontsize = 16, colormap = "plasma")
plt.ylabel('Total Profits',fontsize = 16)
plt.title("Dependancy of Sales,Profits and Discounts",fontsize = 16)

plt.show()

# %% [markdown]
# From this correlation we can conclude that the cities or states having haighest discounts will give low profits and the cities/states with high sales will give high profits.

# %%
df = df.drop(['Postal Code'],axis = 1)    #dropping postal code columns

# %% [markdown]
# # Visualising the value counts

# %%
sns.pairplot(df, hue = 'Ship Mode')

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64

# %%
sns.countplot(x=df['Ship Mode'])
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='count'>

# %%
df['Segment'].value_counts()        #valuecounts for segment
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64

# %%
sns.pairplot(df,hue = 'Segment')     #plotting pair plot

# %%
sns.countplot(x = 'Segment',data = df, palette = 'rainbow')
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='count'>

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: Category, dtype: int64

# %%
sns.countplot(x='Category',data=df,palette='PuRd')
# Out:
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
sns.pairplot(df,hue='Category')

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1522
# Paper          1359
# Furnishings     956
# Phones          889
# Storage         846
# Art             795
# Accessories     775
# Chairs          615
# Appliances      466
# Labels          363
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
plt.figure(figsize=(15,12))
df['Sub-Category'].value_counts().plot.pie(autopct='dark')
plt.show()

# %% [markdown]
# # Checking the profits in different states

# %%
print('total no. of states are : ',  df['State'].nunique())
print(df['State'].value_counts())
# Out:
# total no. of states are :  49
# California              1996
# New York                1127
# Texas                    983
# Pennsylvania             586
# Washington               502
# Illinois                 491
# Ohio                     468
# Florida                  383
# Michigan                 254
# North Carolina           249
# Virginia                 224
# Arizona                  224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   123
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Mississippi               53
# ...

# %%
States_profit = df.groupby('State').sum()['Profit'].sort_values(ascending=False).reset_index()
#sorting the states by their profits in descending order(from highest to lowest profit.)

# %%
plt.figure(figsize=(15,10))
plt.title('Most Profitable States')
sns.barplot(x = 'State',y = 'Profit', data = States_profit.head(15)) #printing first 15 highest profitable states
plt.xticks(rotation = 60 , fontsize = 15) #rotating the labels on x-axis 
plt.yticks(fontsize = 15) 
plt.show()

# %% [markdown]
# ### Total states are 49 , we found the most profitable 15 states so Now, lets find out lowest profitable 15 states from remaining 34 states

# %%
plt.figure(figsize=(15,10))
plt.title('Least Profitable States')
sns.barplot(x = 'State',y = 'Profit', data = States_profit.tail(15)) #printing 15 lowest profitable states
plt.xticks(rotation = 60 , fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()

# %% [markdown]
# Here we can predict that, State with highest profit is California and State with lowest profit is Texas

# %% [markdown]
# # Checking the profits in different cities

# %%
print('Total no. of Cities are : ',  df['City'].nunique())
print(df['City'].value_counts())
# Out:
# Total no. of Cities are :  531
# New York City    914
# Los Angeles      746
# Philadelphia     536
# San Francisco    506
# Seattle          424
#                 ...
# Keller             1
# Chapel Hill        1
# Linden             1
# Lindenhurst        1
# Layton             1
# Name: City, Length: 531, dtype: int64

# %%
city_profit = df.groupby('City').sum()['Profit'].sort_values(ascending = False).reset_index()
#grouping the cities to check the profits in each city and sorting them in descending order from highest to lowest profit.

# %%
plt.figure(figsize=(15,10))
plt.title('Most Profitable Cities')
# sns.barplot(x = city_profit['City'][:15],y = city_profit['Profit'][:15])
sns.barplot(x = 'City',y = 'Profit',data = city_profit.head(15))
plt.xticks(rotation = 60 , fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.title('Least Profitable Cities')
sns.barplot(x = 'City', y = 'Profit', data = city_profit.tail(15)) 
plt.xticks(rotation = 60 , fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()

# %% [markdown]
# Here we can predict that, City with highest profit is New York and city with lowest profit is Philadelphia

# %% [markdown]
# # Checking Sales in different states

# %%
State_sales = df.groupby('State').sum()['Sales'].sort_values(ascending = False).reset_index()

# %%
plt.figure(figsize=(15,10))
plt.title('States with highest sales rate')
sns.barplot(x = 'State', y = 'Sales', data = State_sales.head(15)) 
plt.xticks(rotation = 60 , fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.title('States with lowest sales rate')
sns.barplot(x = 'State', y = 'Sales', data = State_sales.tail(15)) 
plt.xticks(rotation = 60 , fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()

# %% [markdown]
# So from this we can predict that the state having highest sales rate is California and State having lowest sales rate is North Dakota

# %% [markdown]
# # Sales vs Profit

# %%
Sales = df.groupby('State').sum()['Sales'].nlargest(n=15) #top 15 states with highest sales
Profits = df.groupby('State').sum()['Profit'].nlargest(n=15) #top 15 states with highest sales

Sales.plot(kind='bar', figsize=(10,5),fontsize = 15, color = 'lightpink')
Profits.plot(kind='bar', figsize=(10,5),fontsize = 15 , color='Purple')
plt.xlabel('States',fontsize = 15)
plt.ylabel('Total sales and profit',fontsize = 15)
plt.title("Sales vs Profit",fontsize = 15)
plt.show()

# %% [markdown]
# From above plot, we can conclude that California and New York has highest sales and Profits

# %% [markdown]
# ## Profit and sales on Different Categories

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: Category, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Category', data = df)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()

# %%
Category_profit = df.groupby('Category').sum()['Profit'].sort_values(ascending = False)

# %%
plt.figure(figsize=(6,6))
plt.title('Profit on different categories')
Category_profit.plot(kind='bar')
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10)
plt.show()

# %%
Sales = df.groupby('Category').sum()['Sales'].nlargest(n=15) #top 15 states with highest sales
Profits = df.groupby('Category').sum()['Profit'].nlargest(n=15) #top 15 states with highest sales
# plt.style.use('seaborn')
Sales.plot(kind='bar', figsize=(10,5),fontsize = 15, color = 'lightpink')
Profits.plot(kind='bar', figsize=(10,5),fontsize = 15 , color='Purple')
plt.xlabel('Categories',fontsize = 15)
plt.ylabel('Total sales and profit',fontsize = 15)
plt.title("Sales vs Profit",fontsize = 15)
plt.show()

# %% [markdown]
# Here we can conclude that, Technology and Office supplies has the highest sales and profit

# %% [markdown]
# ## Profits and Sales according to subcategory

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1522
# Paper          1359
# Furnishings     956
# Phones          889
# Storage         846
# Art             795
# Accessories     775
# Chairs          615
# Appliances      466
# Labels          363
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Sub-Category', data = df)
plt.xticks(rotation = 90 ,fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()

# %%
SC_profit = df.groupby('Sub-Category').mean()['Profit'].sort_values(ascending = False).reset_index()

# %%
plt.figure(figsize=(15,10))
plt.title('Profits on Sub-Categories')
sns.barplot(x = 'Sub-Category', y = 'Profit', data = SC_profit) 
plt.xticks(rotation = 60 , fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()

# %%
## sub-category with highest loss
min_profit = df.groupby('Sub-Category').min()['Profit'].sort_values()

# %%
plt.figure(figsize=(8,6))
min_profit.plot()
plt.title('Sub-Categories with highest loss')
plt.xticks(rotation = 60 , fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()

# %% [markdown]
# Machines sub-category shows highest loss

# %%
Sales = df.groupby('Sub-Category').mean()['Sales'].sort_values(ascending = False)
Profits = df.groupby('Sub-Category').mean()['Profit'].sort_values(ascending = False)
plt.style.use('seaborn')
Sales.plot(kind='bar', figsize=(10,5),fontsize = 15, color = 'lightpink')
Profits.plot(kind='bar', figsize=(10,5),fontsize = 15 , color='Purple')
plt.xlabel('Sub-Categories',fontsize = 15)
plt.ylabel('Total sales and profit',fontsize = 15)
plt.title("Sales vs Profit",fontsize = 15)
plt.show()

# %% [markdown]
# From above plots, we can conclude that Copiers sub-category shows highest profit with highest sales and Tables shows least profit and sales

# %% [markdown]
# ## Profit on ship modes

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64

# %%
sns.countplot(x='Ship Mode', data = df)
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='count'>

# %%
ship_modes_profit=df.groupby('Ship Mode').mean()['Profit'].sort_values(ascending = False).reset_index()
#Average profit

# %%
plt.figure(figsize=(10,8))
plt.title('Profits on Ship modes')
sns.barplot(x = 'Ship Mode', y = 'Profit', data = ship_modes_profit )
plt.xticks(rotation = 60 , fontsize = 12)
plt.yticks(fontsize = 12)
plt.show()

# %%
ship_modes_discount=df.groupby('Ship Mode').sum()['Discount'].sort_values(ascending = False).reset_index()

plt.figure(figsize=(10,5))
plt.title('Discounts on Ship modes')
sns.barplot(x = 'Ship Mode', y = 'Discount', data = ship_modes_discount )
plt.xticks(rotation = 60 , fontsize = 12)
plt.yticks(fontsize = 12)
plt.show()

# %% [markdown]
# From above two plots we can conclude that Standard class gives more discounts and shows less average profit

# %% [markdown]
# ## Profit according to segment

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64

# %%
sns.countplot(x='Segment', data = df)
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='count'>

# %%
segment_profit=df.groupby('Segment').mean()['Profit'].sort_values(ascending = False).reset_index()

# %%
plt.figure(figsize=(8,5))
plt.title('Profits according to Segments')
sns.barplot(x = 'Segment', y = 'Profit', data = segment_profit )
plt.xticks(rotation = 60 , fontsize = 12)
plt.yticks(fontsize = 12)
plt.show()

# %%
Sales = df.groupby('Segment').mean()['Sales'].sort_values(ascending = False)
Profits = df.groupby('Segment').mean()['Profit'].sort_values(ascending = False)
plt.style.use('seaborn')
Sales.plot(kind='bar', figsize=(10,5),fontsize = 15, color = 'lightpink')
Profits.plot(kind='bar', figsize=(10,5),fontsize = 15 , color='Purple')
plt.xlabel('Segments',fontsize =  15)
plt.ylabel('Total sales and profit',fontsize = 15)
plt.title("Sales vs Profit",fontsize = 15)
plt.show()

# %% [markdown]
# From above plot we can conclude that,Home Office Segment has more profit and sales whereas Consumer Segment has less profit and less sales.

# %% [markdown]
# ## Profit according to Regions

# %%
df['Region'].value_counts()
# Out:
# West       3193
# East       2845
# Central    2319
# South      1620
# Name: Region, dtype: int64

# %%
sns.countplot(x='Region', data = df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
Regions_profit=df.groupby('Region').sum()['Profit'].sort_values(ascending = False).reset_index()

# %%
plt.figure(figsize=(10,5))
plt.title('Profits according to Regions')
sns.barplot(x = 'Region', y = 'Profit', data = Regions_profit )
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.show()

# %%
Sales = df.groupby('Region').sum()['Sales'].sort_values(ascending = False)
Profits = df.groupby('Region').sum()['Profit'].sort_values(ascending = False)
plt.style.use('seaborn')
Sales.plot(kind='bar', figsize=(10,5),fontsize = 15, color = 'lightpink')
Profits.plot(kind='bar', figsize=(10,5),fontsize = 15 , color='Purple')
plt.xlabel('Regions',fontsize =  15)
plt.ylabel('Total sales and profit',fontsize = 15)
plt.title("Sales vs Profit",fontsize = 15)
plt.show()

# %% [markdown]
# From above plot we can conclude that,West Region has more profit and more whereas Central Region has less profit and less sales.

# %%
sns.lineplot(x='Sales',y='Profit',data = df)
plt.show()

# %%
sns.lineplot(x='Discount',y='Profit',data = df)
plt.show()

# %% [markdown]
# Thus we can conclude that, Product sales increases with increase in Discounts but Profit decreases

# %% [markdown]
# Conclusion:
# 1) The cities / states which gives more discounts on products shows more sales but very less profit
#
# 2) West region shows more sales and more profit whereas central region shows least sales and profits. So, we should try to increase sales and profits in central region.
#
# 3) We should limit the discount on standard class shipment and try to increase its sales and profits.
#
# 4)Technology category shows more profit so, we should increse its sales and reduce the sales for furnitures due to its low profit.
#
# 5) Copiers sub-category shows more profit and tables shows least profit so we should also reduce its sales and increase sales for sub-categories like Accessories and Phones
#
# 6) States showing high profit ratios are California and New York whereas States showing least profit ratios are Texas and Ohio
#
# 7)Cities showing high profit ratios are New-york and Los angeles whereas Cities showing least profit ratios are Philidelphia and Housten
